# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mediapipe as mp
import cv2 as cv
import time as time

# %%
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose0 = mp_pose.Pose(static_image_mode=True,min_detection_confidence=0.3, model_complexity=0)
pose1 = mp_pose.Pose(static_image_mode=True,min_detection_confidence=0.3, model_complexity=1)
pose2 = mp_pose.Pose(static_image_mode=True,min_detection_confidence=0.3, model_complexity=2)

# %%
landmarks_pose0 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}
landmarks_pose1 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}
landmarks_pose2 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}

latency_pose0 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}
latency_pose1 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}
latency_pose2 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}

# %%
front_stand_1_1 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Front\1_stand_0000.jpg")
front_stand_1_2 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Front\1_stand_0001.jpg")
front_stand_1_3 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Front\1_stand_0002.jpg")
front_stand_1_4 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Front\1_stand_0003.jpg")
front_stand_1_5 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Front\1_stand_0004.jpg")

side_stand_1_1 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Side\1_stand_0000.jpg")
side_stand_1_2 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Side\1_stand_0000.jpg")
side_stand_1_3 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Side\1_stand_0000.jpg")
side_stand_1_4 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Side\1_stand_0000.jpg")
side_stand_1_5 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Side\1_stand_0000.jpg")

angle_stand_1_1 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Angle\1_stand_0000.jpg")
angle_stand_1_2 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Angle\1_stand_0000.jpg")
angle_stand_1_3 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Angle\1_stand_0000.jpg")
angle_stand_1_4 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Angle\1_stand_0000.jpg")
angle_stand_1_5 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Angle\1_stand_0000.jpg")

# %%
start_time = time.time()
results_front_1_1_pose0 = pose0.process(cv.cvtColor(front_stand_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_2_pose0 = pose0.process(cv.cvtColor(front_stand_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_3_pose0 = pose0.process(cv.cvtColor(front_stand_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_4_pose0 = pose0.process(cv.cvtColor(front_stand_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_5_pose0 = pose0.process(cv.cvtColor(front_stand_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)


start_time = time.time()
results_front_1_1_pose1 = pose1.process(cv.cvtColor(front_stand_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_2_pose1 = pose1.process(cv.cvtColor(front_stand_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_3_pose1 = pose1.process(cv.cvtColor(front_stand_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_4_pose1 = pose1.process(cv.cvtColor(front_stand_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_5_pose1 = pose1.process(cv.cvtColor(front_stand_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)


start_time = time.time()
results_front_1_1_pose2 = pose2.process(cv.cvtColor(front_stand_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_2_pose2 = pose2.process(cv.cvtColor(front_stand_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_3_pose2 = pose2.process(cv.cvtColor(front_stand_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_4_pose2 = pose2.process(cv.cvtColor(front_stand_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_5_pose2 = pose2.process(cv.cvtColor(front_stand_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

# %%
start_time = time.time()
results_side_1_1_pose0 = pose0.process(cv.cvtColor(side_stand_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_2_pose0 = pose0.process(cv.cvtColor(side_stand_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_3_pose0 = pose0.process(cv.cvtColor(side_stand_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_4_pose0 = pose0.process(cv.cvtColor(side_stand_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_5_pose0 = pose0.process(cv.cvtColor(side_stand_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)


start_time = time.time()
results_side_1_1_pose1 = pose1.process(cv.cvtColor(side_stand_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_2_pose1 = pose1.process(cv.cvtColor(side_stand_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_3_pose1 = pose1.process(cv.cvtColor(side_stand_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_4_pose1 = pose1.process(cv.cvtColor(side_stand_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_5_pose1 = pose1.process(cv.cvtColor(side_stand_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)


start_time = time.time()
results_side_1_1_pose2 = pose2.process(cv.cvtColor(side_stand_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_2_pose2 = pose2.process(cv.cvtColor(side_stand_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_3_pose2 = pose2.process(cv.cvtColor(side_stand_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_4_pose2 = pose2.process(cv.cvtColor(side_stand_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_5_pose2 = pose2.process(cv.cvtColor(side_stand_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

# %%
start_time = time.time()
results_angle_1_1_pose0 = pose0.process(cv.cvtColor(angle_stand_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_2_pose0 = pose0.process(cv.cvtColor(angle_stand_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_3_pose0 = pose0.process(cv.cvtColor(angle_stand_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_4_pose0 = pose0.process(cv.cvtColor(angle_stand_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_5_pose0 = pose0.process(cv.cvtColor(angle_stand_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)


start_time = time.time()
results_angle_1_1_pose1 = pose1.process(cv.cvtColor(angle_stand_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_2_pose1 = pose1.process(cv.cvtColor(angle_stand_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_3_pose1 = pose1.process(cv.cvtColor(angle_stand_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_4_pose1 = pose1.process(cv.cvtColor(angle_stand_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_5_pose1 = pose1.process(cv.cvtColor(angle_stand_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)


start_time = time.time()
results_angle_1_1_pose2 = pose2.process(cv.cvtColor(angle_stand_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_2_pose2 = pose2.process(cv.cvtColor(angle_stand_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_3_pose2 = pose2.process(cv.cvtColor(angle_stand_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_4_pose2 = pose2.process(cv.cvtColor(angle_stand_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_5_pose2 = pose2.process(cv.cvtColor(angle_stand_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

# %%
print(latency_pose0)
print(latency_pose1)
print(latency_pose2)
# Out:
# {'Pose1': {'Front': [0.14102649688720703, 0.09501266479492188, 0.10698723793029785, 0.10603046417236328, 0.11100029945373535], 'Side': [0.10499811172485352, 0.12501120567321777, 0.13600969314575195, 0.0980064868927002, 0.10202908515930176], 'Angle': [0.14014101028442383, 0.13598871231079102, 0.10302972793579102, 0.1350095272064209, 0.12001943588256836]}, 'Pose2': {'Front': [], 'Side': [], 'Angle': []}, 'Pose3': {'Front': [], 'Side': [], 'Angle': []}, 'Pose4': {'Front': [], 'Side': [], 'Angle': []}}
# ...

# %%
curr_landmarks_pose0 = results_front_1_1_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_1_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_1_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_1_2_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_2_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_2_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_1_3_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_3_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_3_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_1_4_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_4_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_4_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_1_5_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_5_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_5_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)

# %%
curr_landmarks_pose0 = results_side_1_1_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_1_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_1_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_1_2_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_2_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_2_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_1_3_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_3_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_3_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_1_4_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_4_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_4_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_1_5_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_5_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_5_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)

# %%
curr_landmarks_pose0 = results_angle_1_1_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_1_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_1_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_1_2_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_2_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_2_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_1_3_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_3_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_3_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_1_4_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_4_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_4_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_1_5_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_5_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_5_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)

# %%
print(landmarks_pose0["Pose1"])
print(landmarks_pose1["Pose1"])
print(landmarks_pose2["Pose1"])
# Out:
# {'Front': [{'NOSE': {'x': 0.5200732946395874, 'y': 0.32020312547683716, 'z': -0.48581284284591675}, 'LEFT_EYE_INNER': {'x': 0.5345054268836975, 'y': 0.3068607449531555, 'z': -0.46447545289993286}, 'LEFT_EYE': {'x': 0.5438902378082275, 'y': 0.30692151188850403, 'z': -0.46482551097869873}, 'LEFT_EYE_OUTER': {'x': 0.5508060455322266, 'y': 0.30699971318244934, 'z': -0.4650273323059082}, 'RIGHT_EYE_INNER': {'x': 0.5008504390716553, 'y': 0.3066309094429016, 'z': -0.47056257724761963}, 'RIGHT_EYE': {'x': 0.49053362011909485, 'y': 0.30678892135620117, 'z': -0.47070103883743286}, 'RIGHT_EYE_OUTER': {'x': 0.4820742607116699, 'y': 0.30710747838020325, 'z': -0.47052764892578125}, 'LEFT_EAR': {'x': 0.5595808625221252, 'y': 0.31259387731552124, 'z': -0.304145872592926}, 'RIGHT_EAR': {'x': 0.473269522190094, 'y': 0.312073290348053, 'z': -0.32970449328422546}, 'MOUTH_LEFT': {'x': 0.5379041433334351, 'y': 0.33543750643730164, 'z': -0.42143750190734863}, 'MOUTH_RIGHT': {'x': 0.5018348693847656, 'y': 0
# ...

# %%
combined_avg_values_0 = {}
for pose, values in latency_pose0.items():
    combined_measurements = []
    for category, measurements in values.items():
        combined_measurements.extend(measurements)
    
    if combined_measurements:
        combined_avg_values_0[pose] = sum(combined_measurements) / len(combined_measurements)

combined_avg_values_1 = {}
for pose, values in latency_pose1.items():
    combined_measurements = []
    for category, measurements in values.items():
        combined_measurements.extend(measurements)
    
    if combined_measurements:
        combined_avg_values_1[pose] = sum(combined_measurements) / len(combined_measurements)

combined_avg_values_2 = {}
for pose, values in latency_pose2.items():
    combined_measurements = []
    for category, measurements in values.items():
        combined_measurements.extend(measurements)
    
    if combined_measurements:
        combined_avg_values_2[pose] = sum(combined_measurements) / len(combined_measurements)

# %%
print(combined_avg_values_0)
print(combined_avg_values_1)
print(combined_avg_values_2)
# Out:
# {'Pose1': 0.11735334396362304}
# {'Pose1': 0.1281201680501302}
# {'Pose1': 0.277547025680542}
