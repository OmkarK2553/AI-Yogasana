# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mediapipe as mp
import cv2 as cv
import time as time

# %%
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose0 = mp_pose.Pose(static_image_mode=True,min_detection_confidence=0.3, model_complexity=0)
pose1 = mp_pose.Pose(static_image_mode=True,min_detection_confidence=0.3, model_complexity=1)
pose2 = mp_pose.Pose(static_image_mode=True,min_detection_confidence=0.3, model_complexity=2)

# %%
landmarks_pose0 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}
landmarks_pose1 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}
landmarks_pose2 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}

latency_pose0 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}
latency_pose1 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}
latency_pose2 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}

# %%
front_sit_1_1 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Front\1_sit_0000.jpg")
front_sit_1_2 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Front\1_sit_0001.jpg")
front_sit_1_3 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Front\1_sit_0002.jpg")
front_sit_1_4 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Front\1_sit_0003.jpg")
front_sit_1_5 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Front\1_sit_0004.jpg")

side_sit_1_1 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Side\1_sit_0000.jpg")
side_sit_1_2 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Side\1_sit_0000.jpg")
side_sit_1_3 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Side\1_sit_0000.jpg")
side_sit_1_4 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Side\1_sit_0000.jpg")
side_sit_1_5 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Side\1_sit_0000.jpg")

angle_sit_1_1 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Angle\1_sit_0000.jpg")
angle_sit_1_2 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Angle\1_sit_0000.jpg")
angle_sit_1_3 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Angle\1_sit_0000.jpg")
angle_sit_1_4 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Angle\1_sit_0000.jpg")
angle_sit_1_5 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\comp_study\output_frames\Angle\1_sit_0000.jpg")

# %%
start_time = time.time()
results_front_1_1_pose0 = pose0.process(cv.cvtColor(front_sit_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_2_pose0 = pose0.process(cv.cvtColor(front_sit_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_3_pose0 = pose0.process(cv.cvtColor(front_sit_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_4_pose0 = pose0.process(cv.cvtColor(front_sit_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_5_pose0 = pose0.process(cv.cvtColor(front_sit_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)


start_time = time.time()
results_front_1_1_pose1 = pose1.process(cv.cvtColor(front_sit_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_2_pose1 = pose1.process(cv.cvtColor(front_sit_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_3_pose1 = pose1.process(cv.cvtColor(front_sit_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_4_pose1 = pose1.process(cv.cvtColor(front_sit_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_5_pose1 = pose1.process(cv.cvtColor(front_sit_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)


start_time = time.time()
results_front_1_1_pose2 = pose2.process(cv.cvtColor(front_sit_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_2_pose2 = pose2.process(cv.cvtColor(front_sit_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_3_pose2 = pose2.process(cv.cvtColor(front_sit_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_4_pose2 = pose2.process(cv.cvtColor(front_sit_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_5_pose2 = pose2.process(cv.cvtColor(front_sit_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

# %%
start_time = time.time()
results_side_1_1_pose0 = pose0.process(cv.cvtColor(side_sit_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_2_pose0 = pose0.process(cv.cvtColor(side_sit_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_3_pose0 = pose0.process(cv.cvtColor(side_sit_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_4_pose0 = pose0.process(cv.cvtColor(side_sit_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_5_pose0 = pose0.process(cv.cvtColor(side_sit_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)


start_time = time.time()
results_side_1_1_pose1 = pose1.process(cv.cvtColor(side_sit_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_2_pose1 = pose1.process(cv.cvtColor(side_sit_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_3_pose1 = pose1.process(cv.cvtColor(side_sit_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_4_pose1 = pose1.process(cv.cvtColor(side_sit_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_5_pose1 = pose1.process(cv.cvtColor(side_sit_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)


start_time = time.time()
results_side_1_1_pose2 = pose2.process(cv.cvtColor(side_sit_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_2_pose2 = pose2.process(cv.cvtColor(side_sit_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_3_pose2 = pose2.process(cv.cvtColor(side_sit_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_4_pose2 = pose2.process(cv.cvtColor(side_sit_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_5_pose2 = pose2.process(cv.cvtColor(side_sit_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

# %%
start_time = time.time()
results_angle_1_1_pose0 = pose0.process(cv.cvtColor(angle_sit_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_2_pose0 = pose0.process(cv.cvtColor(angle_sit_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_3_pose0 = pose0.process(cv.cvtColor(angle_sit_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_4_pose0 = pose0.process(cv.cvtColor(angle_sit_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_5_pose0 = pose0.process(cv.cvtColor(angle_sit_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)


start_time = time.time()
results_angle_1_1_pose1 = pose1.process(cv.cvtColor(angle_sit_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_2_pose1 = pose1.process(cv.cvtColor(angle_sit_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_3_pose1 = pose1.process(cv.cvtColor(angle_sit_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_4_pose1 = pose1.process(cv.cvtColor(angle_sit_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_5_pose1 = pose1.process(cv.cvtColor(angle_sit_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)


start_time = time.time()
results_angle_1_1_pose2 = pose2.process(cv.cvtColor(angle_sit_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_2_pose2 = pose2.process(cv.cvtColor(angle_sit_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_3_pose2 = pose2.process(cv.cvtColor(angle_sit_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_4_pose2 = pose2.process(cv.cvtColor(angle_sit_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_5_pose2 = pose2.process(cv.cvtColor(angle_sit_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

# %%
print(latency_pose0)
print(latency_pose1)
print(latency_pose2)
# Out:
# {'Pose1': {'Front': [0.21764397621154785, 0.11801743507385254, 0.12399625778198242, 0.12601065635681152, 0.12028121948242188], 'Side': [0.09302687644958496, 0.12899279594421387, 0.13902759552001953, 0.12698984146118164, 0.1370081901550293], 'Angle': [0.14101004600524902, 0.11200833320617676, 0.09200763702392578, 0.12203025817871094, 0.10541224479675293]}, 'Pose2': {'Front': [], 'Side': [], 'Angle': []}, 'Pose3': {'Front': [], 'Side': [], 'Angle': []}, 'Pose4': {'Front': [], 'Side': [], 'Angle': []}}
# {'Pose1': {'Front': [0.1681537628173828, 0.1710364818572998, 0.16698932647705078, 0.13901400566101074, 0.15600824356079102], 'Side': [0.14635872840881348, 0.13689231872558594, 0.12603116035461426, 0.15699052810668945, 0.13596796989440918], 'Angle': [0.16603732109069824, 0.17101645469665527, 0.18503499031066895, 0.11598825454711914, 0.1430072784423828]}, 'Pose2': {'Front': [], 'Side': [], 'Angle': []}, 'Pose3': {'Front': [], 'Side': [], 'Angle': []}, 'Pose4': {'Front': [], 'Side': [], 'Angle': []}}
# {'Pose1': {'Front': [0.36405062675476074, 0.26999950408935547, 0.26503825187683105, 0.3010225296020508, 0.2960214614868164], 'Side': [0.3000369071960449, 0.315014123916626, 0.2690165042877197, 0.23401808738708496, 0.27604222297668457], 'Angle': [0.2610204219818115, 0.27102208137512207, 0.3150448799133301, 0.26299524307250977, 0.329892635345459]}, 'Pose2': {'Front': [], 'Side': [], 'Angle': []}, 'Pose3': {'Front': [], 'Side': [], 'Angle': []}, 'Pose4': {'Front': [], 'Side': [], 'Angle': []}}

# %%
curr_landmarks_pose0 = results_front_1_1_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_1_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_1_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_1_2_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_2_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_2_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_1_3_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_3_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_3_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_1_4_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_4_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_4_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_1_5_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_5_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_5_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)

# %%
curr_landmarks_pose0 = results_side_1_1_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_1_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_1_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_1_2_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_2_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_2_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_1_3_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_3_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_3_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_1_4_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_4_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_4_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_1_5_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_5_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_5_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)

# %%
curr_landmarks_pose0 = results_angle_1_1_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_1_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_1_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_1_2_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_2_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_2_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_1_3_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_3_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_3_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_1_4_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_4_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_4_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_1_5_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_5_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_5_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)

# %%
print(landmarks_pose0["Pose1"])
print(landmarks_pose1["Pose1"])
print(landmarks_pose2["Pose1"])
# Out:
# {'Front': [{'NOSE': {'x': 0.5040978789329529, 'y': 0.5175784826278687, 'z': -0.18222086131572723}, 'LEFT_EYE_INNER': {'x': 0.5088755488395691, 'y': 0.5040587186813354, 'z': -0.17177578806877136}, 'LEFT_EYE': {'x': 0.5129969716072083, 'y': 0.5039342641830444, 'z': -0.17178915441036224}, 'LEFT_EYE_OUTER': {'x': 0.5168658494949341, 'y': 0.503656804561615, 'z': -0.17180222272872925}, 'RIGHT_EYE_INNER': {'x': 0
746955872, 'z': -0.005291950888931751}, 'LEFT_KNEE': {'x': 0.5890007019042969, 'y': 0.8035837411880493, 'z': -0.18631036579608917}, 'RIGHT_KNEE': {'x': 0.4185887575149536, 'y': 0.7952850461006165, 'z': -0.1825491040945053}, 'LEFT_ANKLE': {'x': 0.47695228457450867, 'y': 0.8582360148429871, 'z': -0.14615648984909058}, 'RIGHT_ANKLE': {'x': 0.520402729511261, 'y': 0.8435233235359192, 'z': -0.12314631044864655}, 'LEFT_HEEL': {'x': 0.46760252118110657, 'y': 0.84955233335495, 'z': -0.1376248300075531}, 'RIGHT_HEEL': {'x': 0.5300574898719788, 'y': 0.8306364417076111, 'z': -0.11147020012140274}, 'LEFT_FOOT_INDEX': {'x': 0.428259015083313, 'y': 0.8836899995803833, 'z': -0.16881109774112701}, 'RIGHT_FOOT_INDEX': {'x': 0.5644957423210144, 'y': 0.8622072339057922, 'z': -0.1360473930835724}}, {'NOSE': {'x': 0.5032665133476257, 'y': 0.5162121057510376, 'z': -0.20077982544898987}, 'LEFT_EYE_INNER': {'x': 0.5090837478637695, 'y': 0.501664936542511, 'z': -0.19475360214710236}, 'LEFT_EYE': {'x': 0.5123162865638733, 'y': 0.5018978118896484, 'z': -0.19487296044826508}, 'LEFT_EYE_OUTER': {'x': 0.5152875185012817, 'y': 0.5019829273223877, 'z': -0.19483838975429535}, 'RIGHT_EYE_INNER': {'x': 0.49890050292015076, 'y': 0.5018504858016968, 'z': -0.19433900713920593}, 'RIGHT_EYE': {'x': 0.4961457848548889, 'y': 0.501922607421875, 'z': -0.19450588524341583}, 'RIGHT_EYE_OUTER': {'x': 0.4926137328147888, 'y': 0.5021928548812866, 'z': -0.19455920159816742}, 'LEFT_EAR': {'x': 0.5193591713905334, 'y': 0.5077182054519653, 'z': -0.1429639607667923}, 'RIGHT_EAR': {'x': 0.4897102117538452, 'y': 0.5085052251815796, 'z': -0.1408601552248001}, 'MOUTH_LEFT': {'x': 0.5103763341903687, 'y': 0.5327212810516357, ' ...

# %%
combined_avg_values_0 = {}
for pose, values in latency_pose0.items():
    combined_measurements = []
    for category, measurements in values.items():
        combined_measurements.extend(measurements)
    
    if combined_measurements:
        combined_avg_values_0[pose] = sum(combined_measurements) / len(combined_measurements)

combined_avg_values_1 = {}
for pose, values in latency_pose1.items():
    combined_measurements = []
    for category, measurements in values.items():
        combined_measurements.extend(measurements)
    
    if combined_measurements:
        combined_avg_values_1[pose] = sum(combined_measurements) / len(combined_measurements)

combined_avg_values_2 = {}
for pose, values in latency_pose2.items():
    combined_measurements = []
    for category, measurements in values.items():
        combined_measurements.extend(measurements)
    
    if combined_measurements:
        combined_avg_values_2[pose] = sum(combined_measurements) / len(combined_measurements)

# %%
print(combined_avg_values_0)
print(combined_avg_values_1)
print(combined_avg_values_2)
# Out:
# {'Pose1': 0.1268975575764974}
# {'Pose1': 0.15230178833007812}
# {'Pose1': 0.2886823654174805}
