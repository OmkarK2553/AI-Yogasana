# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mediapipe as mp
import cv2 as cv
import time as time

# %%
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose0 = mp_pose.Pose(static_image_mode=True,min_detection_confidence=0.3, model_complexity=0)
pose1 = mp_pose.Pose(static_image_mode=True,min_detection_confidence=0.3, model_complexity=1)
pose2 = mp_pose.Pose(static_image_mode=True,min_detection_confidence=0.3, model_complexity=2)

# %%
landmarks_pose0 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}
landmarks_pose1 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}
landmarks_pose2 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}

latency_pose0 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}
latency_pose1 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}
latency_pose2 = {"Pose1":{"Front":[],"Side":[],"Angle":[]},"Pose2":{"Front":[],"Side":[],"Angle":[]},"Pose3":{"Front":[],"Side":[],"Angle":[]},"Pose4":{"Front":[],"Side":[],"Angle":[]}}

# %%
front_1_1 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Front\1_1.png")
front_1_2 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Front\1_2.png")
front_1_3 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Front\1_3.png")
front_1_4 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Front\1_4.png")
front_1_5 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Front\1_5.png")

side_1_1 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Side\1_1.png")
side_1_2 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Side\1_2.png")
side_1_3 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Side\1_3.png")
side_1_4 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Side\1_4.png")
side_1_5 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Side\1_5.png")

angle_1_1 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\45\1_1.png")
angle_1_2 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\45\1_2.png")
angle_1_3 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\45\1_3.png")
angle_1_4 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\45\1_4.png")
angle_1_5 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\45\1_5.png")

# %%
start_time = time.time()
results_front_1_1_pose0 = pose0.process(cv.cvtColor(front_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_2_pose0 = pose0.process(cv.cvtColor(front_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_3_pose0 = pose0.process(cv.cvtColor(front_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_4_pose0 = pose0.process(cv.cvtColor(front_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_5_pose0 = pose0.process(cv.cvtColor(front_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Front"].append(end_time - start_time)


start_time = time.time()
results_front_1_1_pose1 = pose1.process(cv.cvtColor(front_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_2_pose1 = pose1.process(cv.cvtColor(front_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_3_pose1 = pose1.process(cv.cvtColor(front_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_4_pose1 = pose1.process(cv.cvtColor(front_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_5_pose1 = pose1.process(cv.cvtColor(front_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Front"].append(end_time - start_time)


start_time = time.time()
results_front_1_1_pose2 = pose2.process(cv.cvtColor(front_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_2_pose2 = pose2.process(cv.cvtColor(front_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_3_pose2 = pose2.process(cv.cvtColor(front_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_4_pose2 = pose2.process(cv.cvtColor(front_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_1_5_pose2 = pose2.process(cv.cvtColor(front_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Front"].append(end_time - start_time)

# %%
start_time = time.time()
results_side_1_1_pose0 = pose0.process(cv.cvtColor(side_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_2_pose0 = pose0.process(cv.cvtColor(side_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_3_pose0 = pose0.process(cv.cvtColor(side_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_4_pose0 = pose0.process(cv.cvtColor(side_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_5_pose0 = pose0.process(cv.cvtColor(side_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Side"].append(end_time - start_time)


start_time = time.time()
results_side_1_1_pose1 = pose1.process(cv.cvtColor(side_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_2_pose1 = pose1.process(cv.cvtColor(side_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_3_pose1 = pose1.process(cv.cvtColor(side_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_4_pose1 = pose1.process(cv.cvtColor(side_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_5_pose1 = pose1.process(cv.cvtColor(side_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Side"].append(end_time - start_time)


start_time = time.time()
results_side_1_1_pose2 = pose2.process(cv.cvtColor(side_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_2_pose2 = pose2.process(cv.cvtColor(side_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_3_pose2 = pose2.process(cv.cvtColor(side_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_4_pose2 = pose2.process(cv.cvtColor(side_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_1_5_pose2 = pose2.process(cv.cvtColor(side_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Side"].append(end_time - start_time)

# %%
start_time = time.time()
results_angle_1_1_pose0 = pose0.process(cv.cvtColor(angle_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_2_pose0 = pose0.process(cv.cvtColor(angle_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_3_pose0 = pose0.process(cv.cvtColor(angle_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_4_pose0 = pose0.process(cv.cvtColor(angle_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_5_pose0 = pose0.process(cv.cvtColor(angle_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose1"]["Angle"].append(end_time - start_time)


start_time = time.time()
results_angle_1_1_pose1 = pose1.process(cv.cvtColor(angle_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_2_pose1 = pose1.process(cv.cvtColor(angle_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_3_pose1 = pose1.process(cv.cvtColor(angle_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_4_pose1 = pose1.process(cv.cvtColor(angle_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_5_pose1 = pose1.process(cv.cvtColor(angle_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose1"]["Angle"].append(end_time - start_time)


start_time = time.time()
results_angle_1_1_pose2 = pose2.process(cv.cvtColor(angle_1_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_2_pose2 = pose2.process(cv.cvtColor(angle_1_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_3_pose2 = pose2.process(cv.cvtColor(angle_1_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_4_pose2 = pose2.process(cv.cvtColor(angle_1_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_1_5_pose2 = pose2.process(cv.cvtColor(angle_1_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose1"]["Angle"].append(end_time - start_time)

# %%
print(latency_pose0)
print(latency_pose1)
print(latency_pose2)
# Out:
# {'Pose1': {'Front': [0.6349813938140869, 0.10999321937561035, 0.11700749397277832, 0.09698891639709473, 0.09099555015563965], 'Side': [0.13098406791687012, 0.10499453544616699, 0.0900125503540039, 0.09699511528015137, 0.10899949073791504], 'Angle': [0.1059880256652832, 0.11900472640991211, 0.0900266170501709, 0.09699797630310059, 0.09597492218017578]}, 'Pose2': {'Front': [], 'Side': [], 'Angle': []}, 'Pose3': {'Front': [], 'Side': [], 'Angle': []}, 'Pose4': {'Front': [], 'Side': [], 'Angle': []}}
# ...

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

if results_front_1_1_pose0.pose_landmarks:
    img_copy = front_1_1.copy()
    mp_drawing.draw_landmarks(image=img_copy,landmark_list=results_front_1_1_pose0.pose_landmarks,connections=mp_pose.POSE_CONNECTIONS)
    axes[0].imshow(img_copy[:,:,::-1])
    axes[0].set_title("Output image-0")
    axes[0].axis("Off")

if results_front_1_1_pose0.pose_landmarks:
    img_copy = front_1_1.copy()
    mp_drawing.draw_landmarks(image=img_copy,landmark_list=results_front_1_1_pose0.pose_landmarks,connections=mp_pose.POSE_CONNECTIONS)
    axes[1].imshow(img_copy[:,:,::-1])
    axes[1].set_title("Output image-1")
    axes[1].axis("Off")

if results_front_1_1_pose0.pose_landmarks:
    img_copy = front_1_1.copy()
    mp_drawing.draw_landmarks(image=img_copy,landmark_list=results_front_1_1_pose0.pose_landmarks,connections=mp_pose.POSE_CONNECTIONS)
    axes[2].imshow(img_copy[:,:,::-1])
    axes[2].set_title("Output image-2")
    axes[2].axis("Off")

plt.tight_layout()
plt.show()

# %%
curr_landmarks_pose0 = results_front_1_1_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_1_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_1_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_1_2_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_2_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_2_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_1_3_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_3_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_3_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_1_4_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_4_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_4_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_1_5_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_1_5_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_1_5_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Front"].append(curr_dict)

# %%
curr_landmarks_pose0 = results_side_1_1_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_1_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_1_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_1_2_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_2_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_2_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_1_3_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_3_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_3_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_1_4_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_4_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_4_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_1_5_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_1_5_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_1_5_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Side"].append(curr_dict)

# %%
curr_landmarks_pose0 = results_angle_1_1_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_1_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_1_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_1_2_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_2_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_2_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_1_3_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_3_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_3_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_1_4_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_4_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_4_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_1_5_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_1_5_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose1"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_1_5_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose1"]["Angle"].append(curr_dict)

# %% [markdown]
# POSE 2

# %%
front_2_1 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Front\2_1.png")
front_2_2 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Front\2_2.png")
front_2_3 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Front\2_3.png")
front_2_4 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Front\2_4.png")
front_2_5 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Front\2_5.png")

side_2_1 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Side\2_1.png")
side_2_2 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Side\2_2.png")
side_2_3 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Side\2_3.png")
side_2_4 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Side\2_4.png")
side_2_5 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\Side\2_5.png")

angle_2_1 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\45\2_1.png")
angle_2_2 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\45\2_2.png")
angle_2_3 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\45\2_3.png")
angle_2_4 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\45\2_4.png")
angle_2_5 = cv.imread(r"D:\OpenCV Practice\Comparative_Study\yoga_benchmarking\45\2_5.png")

# %%
start_time = time.time()
results_front_2_1_pose0 = pose0.process(cv.cvtColor(front_2_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_2_2_pose0 = pose0.process(cv.cvtColor(front_2_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_2_3_pose0 = pose0.process(cv.cvtColor(front_2_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_2_4_pose0 = pose0.process(cv.cvtColor(front_2_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_2_5_pose0 = pose0.process(cv.cvtColor(front_2_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Front"].append(end_time - start_time)


start_time = time.time()
results_front_2_1_pose1 = pose1.process(cv.cvtColor(front_2_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_2_2_pose1 = pose1.process(cv.cvtColor(front_2_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_2_3_pose1 = pose1.process(cv.cvtColor(front_2_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_2_4_pose1 = pose1.process(cv.cvtColor(front_2_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_2_5_pose1 = pose1.process(cv.cvtColor(front_2_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Front"].append(end_time - start_time)


start_time = time.time()
results_front_2_1_pose2 = pose2.process(cv.cvtColor(front_2_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_2_2_pose2 = pose2.process(cv.cvtColor(front_2_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_2_3_pose2 = pose2.process(cv.cvtColor(front_2_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_2_4_pose2 = pose2.process(cv.cvtColor(front_2_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Front"].append(end_time - start_time)

start_time = time.time()
results_front_2_5_pose2 = pose2.process(cv.cvtColor(front_2_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Front"].append(end_time - start_time)

# %%
start_time = time.time()
results_side_2_1_pose0 = pose0.process(cv.cvtColor(side_2_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_2_2_pose0 = pose0.process(cv.cvtColor(side_2_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_2_3_pose0 = pose0.process(cv.cvtColor(side_2_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_2_4_pose0 = pose0.process(cv.cvtColor(side_2_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_2_5_pose0 = pose0.process(cv.cvtColor(side_2_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Side"].append(end_time - start_time)


start_time = time.time()
results_side_2_1_pose1 = pose1.process(cv.cvtColor(side_2_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_2_2_pose1 = pose1.process(cv.cvtColor(side_2_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_2_3_pose1 = pose1.process(cv.cvtColor(side_2_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_2_4_pose1 = pose1.process(cv.cvtColor(side_2_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_2_5_pose1 = pose1.process(cv.cvtColor(side_2_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Side"].append(end_time - start_time)


start_time = time.time()
results_side_2_1_pose2 = pose2.process(cv.cvtColor(side_2_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_2_2_pose2 = pose2.process(cv.cvtColor(side_2_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_2_3_pose2 = pose2.process(cv.cvtColor(side_2_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_2_4_pose2 = pose2.process(cv.cvtColor(side_2_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Side"].append(end_time - start_time)

start_time = time.time()
results_side_2_5_pose2 = pose2.process(cv.cvtColor(side_2_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Side"].append(end_time - start_time)

# %%
start_time = time.time()
results_angle_2_1_pose0 = pose0.process(cv.cvtColor(angle_2_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_2_2_pose0 = pose0.process(cv.cvtColor(angle_2_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_2_3_pose0 = pose0.process(cv.cvtColor(angle_2_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_2_4_pose0 = pose0.process(cv.cvtColor(angle_2_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_2_5_pose0 = pose0.process(cv.cvtColor(angle_2_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose0["Pose2"]["Angle"].append(end_time - start_time)


start_time = time.time()
results_angle_2_1_pose1 = pose1.process(cv.cvtColor(angle_2_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_2_2_pose1 = pose1.process(cv.cvtColor(angle_2_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_2_3_pose1 = pose1.process(cv.cvtColor(angle_2_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_2_4_pose1 = pose1.process(cv.cvtColor(angle_2_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_2_5_pose1 = pose1.process(cv.cvtColor(angle_2_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose1["Pose2"]["Angle"].append(end_time - start_time)


start_time = time.time()
results_angle_2_1_pose2 = pose2.process(cv.cvtColor(angle_2_1,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_2_2_pose2 = pose2.process(cv.cvtColor(angle_2_2,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_2_3_pose2 = pose2.process(cv.cvtColor(angle_2_3,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_2_4_pose2 = pose2.process(cv.cvtColor(angle_2_4,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Angle"].append(end_time - start_time)

start_time = time.time()
results_angle_2_5_pose2 = pose2.process(cv.cvtColor(angle_2_5,cv.COLOR_BGR2RGB))
end_time = time.time()
latency_pose2["Pose2"]["Angle"].append(end_time - start_time)

# %%
print(latency_pose0)
print(latency_pose1)
print(latency_pose2)
# Out:
# {'Pose1': {'Front': [0.6349813938140869, 0.10999321937561035, 0.11700749397277832, 0.09698891639709473, 0.09099555015563965], 'Side': [0.13098406791687012, 0.10499453544616699, 0.0900125503540039, 0.09699511528015137, 0.10899949073791504], 'Angle': [0.1059880256652832, 0.11900472640991211, 0.0900266170501709, 0.09699797630310059, 0.09597492218017578]}, 'Pose2': {'Front': [0.14200735092163086, 0.13297295570373535, 0.17604970932006836, 0.14998936653137207, 0.17895960807800293, 0.11199784278869629, 0.10000491142272949, 0.09599423408508301, 0.08701181411743164, 0.08801507949829102], 'Side': [0.12801122665405273, 0.14001679420471191, 0.1999664306640625, 0.11400723457336426, 0.11500167846679688, 0.13698577880859375, 0.14802765846252441, 0.14599871635437012, 0.15101885795593262, 0.12397217750549316], 'Angle': [0.17600345611572266, 0.16598820686340332, 0.180009126663208, 0.194990873336792, 0.2199854850769043]}, 'Pose3': {'Front': [], 'Side': [], 'Angle': []}, 'Pose4': {'Front': [], 'Side': [
# ...

# %%
curr_landmarks_pose0 = results_front_2_1_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_2_1_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_2_1_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_2_2_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_2_2_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_2_2_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_2_3_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_2_3_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_2_3_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_2_4_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_2_4_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_2_4_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Front"].append(curr_dict)



curr_landmarks_pose0 = results_front_2_5_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Front"].append(curr_dict)

curr_landmarks_pose1 = results_front_2_5_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Front"].append(curr_dict)

curr_landmarks_pose2 = results_front_2_5_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Front"].append(curr_dict)

# %%
curr_landmarks_pose0 = results_side_2_1_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_2_1_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_2_1_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_2_2_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_2_2_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_2_2_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_2_3_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_2_3_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_2_3_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_2_4_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_2_4_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_2_4_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Side"].append(curr_dict)



curr_landmarks_pose0 = results_side_2_5_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Side"].append(curr_dict)

curr_landmarks_pose1 = results_side_2_5_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Side"].append(curr_dict)

curr_landmarks_pose2 = results_side_2_5_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Side"].append(curr_dict)

# %%
curr_landmarks_pose0 = results_angle_2_1_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_2_1_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_2_1_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_2_2_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_2_2_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_2_2_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_2_3_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_2_3_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_2_3_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_2_4_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_2_4_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_2_4_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Angle"].append(curr_dict)



curr_landmarks_pose0 = results_angle_2_5_pose0.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose0):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose0["Pose2"]["Angle"].append(curr_dict)

curr_landmarks_pose1 = results_angle_2_5_pose1.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose1):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose1["Pose2"]["Angle"].append(curr_dict)

curr_landmarks_pose2 = results_angle_2_5_pose2.pose_landmarks.landmark
curr_dict = {}
for idx, landmark in enumerate(curr_landmarks_pose2):
    curr_dict[mp_pose.PoseLandmark(idx).name] = {        
        'x': landmark.x,
        'y': landmark.y,
        'z': landmark.z
    }
landmarks_pose2["Pose2"]["Angle"].append(curr_dict)
